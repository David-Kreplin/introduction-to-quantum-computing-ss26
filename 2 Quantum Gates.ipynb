# %% [markdown]
# ## Introduction to Quantum Computing: Labs
#
# ### Lab 2: Single-Qubit Quantum Gates

# %% [markdown]
# In the previous lab, we created quantum circuits and studied the outcomes of measurements.
# In this lab, we investigate the mathematical description of quantum states and quantum gates, and investigate the action of single-qubit gates.
#
# This notebook contains many short exercises. In many cases, you will reuse very similar code, so you may simply copy code from one cell to the next and adjust the gates in the quantum circuit as needed.
#
# We start with a repetition of the gates we know and how circuits containing them can be created in Qiskit.

# %%
from qiskit import QuantumCircuit
import numpy as np

# Initialize an empty quantum circuit with one qubit
quantum_circuit = QuantumCircuit(1)

# Add a Hadamard gate to the first qubit
quantum_circuit.h(0)

# Add an Z gate to the first qubit
quantum_circuit.z(0)

# Add an X gate to the first qubit
quantum_circuit.x(0)

# Generate a visual representation of the circuit
quantum_circuit.draw('mpl')

# %% [markdown]
# ### Calculating Statevectors and Quantum States from Quantum Circuits

# %% [markdown]
# Qiskit can calculate the resulting quantum state of a quantum circuit.
# Reminder: the quantum state of a qubit can be written in two equivalent notations ($\alpha, \beta$ are amplitudes):
#
# - Statevector: $\ket{\psi} = \begin{pmatrix} \alpha \\ \beta \end{pmatrix}$
# - Quantum state (Dirac notation): $\ket{\psi} = \alpha \ket{0} + \beta \ket{1}$
#
# To determine both expressions for a given quantum circuit, we use the following functions from the helper library ``qc_lecture_tools``:
#
# > - ``sv_vector(quantum_circuit, label=None)``: displays the resulting **statevector** of a quantum circuit
# >
# > - ``sv_state(quantum_circuit, label=None)``: displays the resulting **quantum state** of a quantum circuit
# >
# > - ``sv_probs(quantum_circuit, label=None)``: displays the resulting **measurement probabilities** after applying the quantum circuit
#
# All functions have an optional second argument for a label. The representations can be displayed at any time using ``display()``.

# %%
from qc_lecture_tools.statevector import sv_vector, sv_state, sv_probs  # Import helper functions

# %%
# You can copy this code snippet throughout the lab to obtain the statevector,
# quantum state, and measurement probabilities of your quantum circuit.

# Example: Hadamard gate
quantum_circuit = QuantumCircuit(1)
quantum_circuit.h(0)

# Output of the statevector, quantum state, and measurement probabilities
display(sv_vector(quantum_circuit, "Statevector: "))
display(sv_state(quantum_circuit, "Quantum state: "))
display(sv_probs(quantum_circuit, "Measurement probabilities: "))
# Out:
# $\displaystyle \text{ Statevector:  }\begin{pmatrix}\frac{\sqrt{2}}{2}\\\frac{\sqrt{2}}{2}\\\end{pmatrix}$
# $\displaystyle \text{ Quantum state:  }\frac{\sqrt{2}}{2} |0\rangle+\frac{\sqrt{2}}{2} |1\rangle$
# $\displaystyle \text{ Measurement probabilities:  }\begin{array}{rcl}p_{0} & = & \frac{1}{2} \\m]p_{1} & = & \frac{1}{2} \\m]\end{array}$

# %% [markdown]
# ### Exercise 1: Basics
#
# **Exercise 1.1:** Create an empty circuit and compute the statevector, the quantum state, and the measurement probabilities.

# %%
# TODO Exercise 1.1

# %% [markdown]
# **Exercise 1.2:** Repeat the analysis after adding an $X$ gate to the circuit.

# %%
# TODO Exercise 1.2

# %% [markdown]
# **Exercise 1.3:** The $Z$ gate and the $H$ gate.
#
# We have seen that an $X$ gate flips the computational basis states. Single-qubit quantum gates are completely determined by their action on the two basis states $\ket{0}$ and $\ket{1}$.
# Investigate the action of the $Z$ gate and the $H$ gate on the basis states $\ket{0}$ and $\ket{1}$. Remember that you first need to use the $X$ gate to prepare the $\ket{1}$ state.

# %%
# TODO Exercise 1.3

# %% [markdown]
# ### Exercise 2: The Y, S, and T Gates
#
# We now investigate three gates that have not yet been introduced in the lecture.
#
# Investigate the effect of the $Y$, $S$, and $T$ gates on the basis states $\ket{0}$ and $\ket{1}$ using the functions above.
# Then determine the matrix representation of each gate by using the resulting statevectors as the columns of the matrix.
# (You can copy the code from the previous cells and manually add the Y, S, or T gate.)
#
# The gates can be added in Qiskit as follows:
#
# - Y gate: ``QuantumCircuit.y(0)``
#
# - S gate: ``QuantumCircuit.s(0)``
#
# - T gate: ``QuantumCircuit.t(0)``

# %% [markdown]
# **Exercise 2.1:** Analysis of the Y gate.

# %%
# TODO Exercise 2.1

# %% [markdown]
# **Exercise 2.2:** Analysis of the S gate.

# %%
# TODO Exercise 2.2

# %% [markdown]
# **Exercise 2.3:** Analysis of the T gate.

# %%
# TODO Exercise 2.3

# %% [markdown]
# The complex expression can be written in polar form as $\frac{\sqrt{2}(1+i)}{2} = e^{i\pi/4}$.

# %% [markdown]
# ## Exercise 3: Multiple Gates

# %% [markdown]
# Next, we analyze how applying multiple gates in sequence affects the result and how this can be used to control the measurement probabilities.

# %% [markdown]
# **Exercise 3.1:** Analyze the effect of applying the following pairs of gates in succession: $HH$, $XX$, $YY$, $ZZ$. Investigate the effect either on the two basis states or, alternatively, on the 50/50 superposition state produced by the Hadamard gate (``.h()``).

# %%
# TODO Exercise 3.1

# %% [markdown]
# **Exercise 3.2:** What happens when you apply two $S$ gates and two $T$ gates in succession? (Use the same procedure as in Exercise 3.1.)

# %%
# TODO Exercise 3.2

# %% [markdown]
# **Exercise 3.3:** Investigate how the order of the $Y$ and $H$ gates affects the final state. Which order leads to which result?

# %%
# TODO Exercise 3.3

# %% [markdown]
# **Exercise 3.4:** Investigate what happens when you apply the following gate combinations: $HXH$ and $HZH$.

# %%
# TODO Exercise 3.4

# %% [markdown]
# **Exercise 3.5:** So far, we have only obtained probabilities of $p_0 = 1$, $p_1 = 1$, or $p_0 = 0.5$ and $p_1 = 0.5$.
# Try using more than two gates from the set $\{X, Y, Z, H, S, T\}$ to obtain other probabilities. What do you notice?

# %%
# TODO Exercise 3.5

# %% [markdown]
# **Exercise 3.6:** Investigate the effect of applying a rotation gate at the end of the circuit.
#
# Note, a rotational gate can be added by:
#
# > ``quantum_circuit.ry(angle, 0)`` in which `anlge` is the angle of the rotation in radian (from degree times $\pi / 180$)
#
# Test out the angles $5\pi / 3$ and $\pi$, and arbitrary angles between $0$ and $\pi$.

# %%
# TODO Exercise 3.6

# %% [markdown]
# ## Exercise 4: Finding Quantum Circuits for Given States
#
# We now reverse the problem: given a target quantum state, find a quantum circuit consisting of several quantum gates that prepares this state.
# If a rotation gate is needed, the angle is already provided.

# %% [markdown]
# **Exercise 4.1:** Find a quantum circuit that prepares the state $\ket{\psi_1} = \frac{\sqrt{2}}{2}\ket{0} - \frac{\sqrt{2}}{2}\ket{1}$.

# %%
# TODO Exercise 4.1

# %% [markdown]
# **Exercise 4.2:** Find a quantum circuit that prepares the state $\ket{\psi_2} = \frac{\sqrt{2}i}{2}\ket{0} - \frac{\sqrt{2}i}{2}\ket{1}$.

# %%
# TODO Exercise 4.2

# %% [markdown]
# **Exercise 4.3:** Find a quantum circuit that prepares the state $\ket{\psi_3} = \frac{\sqrt{2}}{2}\ket{0} - \frac{\sqrt{2}i}{2}\ket{1}$.

# %%
# TODO Exercise 4.3

# %% [markdown]
# **Exercise 4.4:** Find a quantum circuit that prepares the state $\ket{\psi_4} = i\ket{0}$.

# %%
# TODO Exercise 4.4

# %% [markdown]
# **Exercise 4.5:** Find a quantum circuit that prepares the state $\ket{\psi_5} = -i\ket{1}$.

# %%
# TODO Exercise 4.5

# %% [markdown]
# **Exercise 4.6:** Find a quantum circuit that prepares the state $\ket{\psi_6} = \left(\frac{1}{2} + \frac{i}{2}\right)\ket{0} + \left(\frac{1}{2} + \frac{i}{2}\right)\ket{1}$.
# (Difficult: four gates are needed. Work through the construction step by step.)

# %%
# TODO Exercise 4.6
